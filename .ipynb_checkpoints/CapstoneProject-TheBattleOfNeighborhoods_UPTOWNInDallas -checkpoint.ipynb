# %% [markdown]
# # Coursera Capstone Project
# ## The Battle of Neighborhoods (Week 1)

# %% [markdown]
# The report content:
#     - A description of the problem and a discussion of the background
#     - A description of the problem and a discussion of the background
#     - Download and Explore Dataset
#     - Data will be gather from Foursquare
#         Explore a Given Venue (Apartments)
#         Explore a Given Venue (Shop & Service)
#         Explore a Given Venue (Restaurant)
#         Explore a Given Venue (Medical Center)
#         Explore a Given Venue (School)
#         Explore a Given Venue (Road)
#     - 45 venues categories
#     - Result and conclusion

# %% [markdown]
# ### Part 1 : A description of the problem and a discussion of the background.
#
# The problem is my husband and myself want to move to Dallas and rent an appartment close to his work, the question is where we should go? we care about:
# The life style,
# The safeity,
# The traffic in the area,
# The appartment need to be 2 bedrooms and 2 bathrooms,
# price of rent not more that $2,000.00 a month,
# Having venues such as coffee shops, restaurants and mall near by.
# So we are going to look for the nighboor hood in dallas near to Down Town Dallas and compair.(manily we will compair between Irving and Richirdson)

# %% [markdown]
# This problem could be applicable to anyone want to move to Dallas for example and having similar cratiera, and we care, because we need an answer to that question, and this problem could be helpful to anyone want to learn how toanswer similar question and parctise a data science real life problem.

# %% [markdown]
# ### Part 2 :A description of the data and how it will be used to solve the problem.

# %% [markdown]
# The required data are:
# The neighborhoods of Down Town Dallas with their geodata (latitud and longitud) (manily we will compair between Irving and Richirdson)
# The of apartments for rent in Irving and Richirdson area (price, life style, shopping)
# The Venues in Irving and Richirdson
#
# how the data will be used to solve the problem:
#
# From Foursquare find top 10 venues for Dallas neighborhoods and clustered in groups
# From Foursquare find location of rental places,with price detials.
# From Foursquare find the venues.
# and compare between Irving and Richirdson.

# %% [markdown]
# --------------------------------------------------------------------------

# %% [markdown]
# First let's download all libraries we need

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Download and Explore Dataset

# %% [markdown]
# Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'IBMDHJ3EQQMYCEKTWBME1UADKR5CVT1DANIW4CZNXPCOIDY5' # your Foursquare ID
CLIENT_SECRET = 'VJVVBQN14QFTAR2DSG4JONF1ZPG2MCB3DOSKDC3RWJ14IYTG' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: IBMDHJ3EQQMYCEKTWBME1UADKR5CVT1DANIW4CZNXPCOIDY5
# CLIENT_SECRET:VJVVBQN14QFTAR2DSG4JONF1ZPG2MCB3DOSKDC3RWJ14IYTG

# %% [markdown]
# ## Data will be gather from Foursquare

# %%
address = 'UpTown, TX'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 32.8007124 -96.7998571

# %% [markdown]
# #### Search for a specific venue category (apartment)

# %%
search_query = 'apartment'
radius = 500
print(search_query + ' .... OK!')
# Out:
# apartment .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IBMDHJ3EQQMYCEKTWBME1UADKR5CVT1DANIW4CZNXPCOIDY5&client_secret=VJVVBQN14QFTAR2DSG4JONF1ZPG2MCB3DOSKDC3RWJ14IYTG&ll=32.8007124,-96.7998571&v=20180604&query=apartment&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d28b02dfd16bb002ce02188'},
#  'response': {'venues': [{'id': '4efe48ce29c201c6fbe77e9b',
#     'name': 'Apartment Agents',
#     'location': {'address': '3131 McKinney Ave',
#      'lat': 32.80268,
#      'lng': -96.80085,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.80268,
#        'lng': -96.80085}],
#      'distance': 237,
#      'postalCode': '75204',
#      'cc': 'US',
#      'city': 'Dallas',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['3131 McKinney Ave',
#       'Dallas, TX 75204',
#       'United States']},
#     'categories': [{'id': '56aa371be4b08b9a8d573552',
#       'name': 'Rental Service',
#       'pluralName': 'Rental Services',
#       'shortName': 'Rental Service',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '153917492'},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '56aa371be4b08b9a8d573552', 'name': 'R...    False
# 1  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...    False
# 2  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 3  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 4  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
#
#                          id    location.address location.cc location.city  \
# 0  4efe48ce29c201c6fbe77e9b   3131 McKinney Ave          US        Dallas
# 1  57c706e0498eb340bc48a3dd       3033 Routh St          US        Dallas
# 2  4cddc2f27e2e236a41d97a1b   3010 State Street          US        Dallas
# 3  5bc8e6562b9844002cdf801d  3411 Oak Grove Ave          US        Dallas
# 4  4f0ef548e4b0ac27394e54c6   3324 McKinney Ave          US        Dallas
#
#   location.country  location.distance  \
# 0    United States                237
# 1    United States                459
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                  name  \
# 0                    Apartment Agents
# 1          Street Flats Apartment Gym
# 2  Manchester State Thomas Apartments
# 3            One Oak Grove Apartments
# 4    Hosting.com Corporate Apartments
# 5      Monaco on the Trail Apartments
#
#                                  categories             address  cc    city  \
# 0                            Rental Service   3131 McKinney Ave  US  Dallas
# 1                                       Gym       3033 Routh St  US  Dallas
# 2  Residential Building (Apartment / Condo)   3010 State Street  US  Dallas
# 3  Residential Building (Apartment / Condo)  3411 Oak Grove Ave  US  Dallas
# 4  Residential Building (Apartment / Condo)   3324 McKinney Ave  US  Dallas
# 5                                  Building    3003 Carlisle St  US  Dallas
#
#          country  distance                                   formattedAddress  \
# 0  United States       237  [3131 McKinney Ave, Dallas, TX 75204, United S...
# ...

# %% [markdown]
# Let's visualize the apartment that are nearby

# %%
dataframe_filtered.name
# Out:
# 0                      Apartment Agents
# 1            Street Flats Apartment Gym
# 2    Manchester State Thomas Apartments
# 3              One Oak Grove Apartments
# 4      Hosting.com Corporate Apartments
# 5        Monaco on the Trail Apartments
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Will explore Appartemts, Shopes and services, schools, medical centers, resurants and near highwys. in UpTown area

# %% [markdown]
# ## Explore a Given Venue  (Apartments)

# %% [markdown]
# Monaco on the Trail Apartments

# %%
search_query = 'Monaco on the Trail Apartments'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Monaco on the Trail Apartments .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IBMDHJ3EQQMYCEKTWBME1UADKR5CVT1DANIW4CZNXPCOIDY5&client_secret=VJVVBQN14QFTAR2DSG4JONF1ZPG2MCB3DOSKDC3RWJ14IYTG&ll=32.8007124,-96.7998571&v=20180604&query=Monaco on the Trail Apartments&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d28b3c16adbf5002ce65552'},
#  'response': {'venues': [{'id': '526406b611d2657120a5adab',
#     'name': 'Monaco on the Trail Apartments',
#     'location': {'address': '3003 Carlisle St',
#      'lat': 32.80323,
#      'lng': -96.8032,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.80323,
#        'lng': -96.8032}],
#      'distance': 419,
#      'postalCode': '75204',
#      'cc': 'US',
#      'city': 'Dallas',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['3003 Carlisle St',
#       'Dallas, TX 75204',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '419408181'},
# ...

# %%
venue_id = '526406b611d2657120a5adab' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/526406b611d2657120a5adab?client_id=IBMDHJ3EQQMYCEKTWBME1UADKR5CVT1DANIW4CZNXPCOIDY5&client_secret=VJVVBQN14QFTAR2DSG4JONF1ZPG2MCB3DOSKDC3RWJ14IYTG&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'likes', 'dislike', 'ok', 'venueRatingBlacklisted', 'beenHere', 'specials', 'photos', 'venuePage', 'reasons', 'description', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '526406b611d2657120a5adab',
#  'name': 'Monaco on the Trail Apartments',
#  'contact': {'phone': '2148555211',
#   'formattedPhone': '(214) 855-5211',
#   'twitter': 'monacokatytrail',
#   'facebook': '387300141375528',
#   'facebookUsername': 'MonacoOnTheTrail',
#   'facebookName': 'Monaco on the Trail Apartments'},
#  'location': {'address': '3003 Carlisle St',
#   'lat': 32.80323,
#   'lng': -96.8032,
#   'labeledLatLngs': [{'label': 'display', 'lat': 32.80323, 'lng': -96.8032}],
#   'postalCode': '75204',
#   'cc': 'US',
#   'city': 'Dallas',
#   'state': 'TX',
#   'country': 'United States',
# ...

# %% [markdown]
#  Get the venue's overall rating of Monaco on the Trail Apartments

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Hosting.com Corporate Apartments

# %%
venue_id = '4f0ef548e4b0ac27394e54c6' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4f0ef548e4b0ac27394e54c6?client_id=IBMDHJ3EQQMYCEKTWBME1UADKR5CVT1DANIW4CZNXPCOIDY5&client_secret=VJVVBQN14QFTAR2DSG4JONF1ZPG2MCB3DOSKDC3RWJ14IYTG&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'venueRatingBlacklisted', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '4f0ef548e4b0ac27394e54c6',
#  'name': 'Hosting.com Corporate Apartments',
#  'contact': {},
#  'location': {'address': '3324 McKinney Ave',
#   'lat': 32.804577362784265,
#   'lng': -96.7988866949907,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 32.804577362784265,
#     'lng': -96.7988866949907}],
#   'postalCode': '75204',
#   'cc': 'US',
#   'city': 'Dallas',
#   'state': 'TX',
#   'country': 'United States',
#   'formattedAddress': ['3324 McKinney Ave',
#    'Dallas, TX 75204',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/hostingcom-corporate-apartments/4f0ef548e4b0ac27394e54c6',
#  'categories': [{'id': '4d954b06a243a5684965b473',
# ...

# %% [markdown]
# Get the venue's overall rating of Hosting.com Corporate Apartments

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# Manchester State Thomas Apartments

# %%
venue_id = '4cddc2f27e2e236a41d97a1b' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4cddc2f27e2e236a41d97a1b?client_id=IBMDHJ3EQQMYCEKTWBME1UADKR5CVT1DANIW4CZNXPCOIDY5&client_secret=VJVVBQN14QFTAR2DSG4JONF1ZPG2MCB3DOSKDC3RWJ14IYTG&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'likes', 'dislike', 'ok', 'venueRatingBlacklisted', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'storeId', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '4cddc2f27e2e236a41d97a1b',
#  'name': 'Manchester State Thomas Apartments',
#  'contact': {'phone': '2149999320',
#   'formattedPhone': '(214) 999-9320',
#   'twitter': 'manchestrstthom',
#   'facebook': '291390240205',
#   'facebookUsername': 'ManchesterStateThomas',
#   'facebookName': 'Manchester State Thomas-Dallas'},
#  'location': {'address': '3010 State Street',
#   'lat': 32.799069907807166,
#   'lng': -96.79543936638484,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 32.799069907807166,
#     'lng': -96.79543936638484}],
#   'postalCode': '75204',
#   'cc': 'US',
#   'city': 'Dallas',
# ...

# %% [markdown]
# Get the venue's overall rating of Manchester State Thomas Apartments

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# All the apartment we looked at is not rate it yet.

# %% [markdown]
# ## Explore a Given Venue  (Shop & Service)

# %%
search_query = 'Shop & Service'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Shop & Service .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IBMDHJ3EQQMYCEKTWBME1UADKR5CVT1DANIW4CZNXPCOIDY5&client_secret=VJVVBQN14QFTAR2DSG4JONF1ZPG2MCB3DOSKDC3RWJ14IYTG&ll=32.8007124,-96.7998571&v=20180604&query=Shop & Service&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d28b9cabf7dde002ce1d7ca'},
#  'response': {'venues': [{'id': '4c7ae808278eb71301905d80',
#     'name': "Ann's Gift Shop",
#     'location': {'address': '2808 McKinney Ave',
#      'crossStreet': 'Worthington',
#      'lat': 32.798288,
#      'lng': -96.800445,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.798288,
#        'lng': -96.800445}],
#      'distance': 275,
#      'postalCode': '75204',
#      'cc': 'US',
#      'city': 'Dallas',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['2808 McKinney Ave (Worthington)',
#       'Dallas, TX 75204',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...    False
# 1                                                 []    False
# 2  [{'id': '4bf58dd8d48988d11a951735', 'name': 'B...    False
#
#                          id   location.address location.cc location.city  \
# 0  4c7ae808278eb71301905d80  2808 McKinney Ave          US        Dallas
# 1  4d6fe6510d996dcba1ffbd8e                NaN          US           NaN
# 2  5c840f76da7080002c06ebd9                NaN          US        Dallas
#
#   location.country location.crossStreet  location.distance  \
# 0    United States          Worthington                275
# 1    United States                  NaN                351
# 2    United States                  NaN                521
#
#                            location.formattedAddress  \
# 0  [2808 McKinney Ave (Worthington), Dallas, TX 7...
# 1                             [Texas, United States]
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                      name     categories            address  cc    city  \
# 0         Ann's Gift Shop  Grocery Store  2808 McKinney Ave  US  Dallas
# 1  Sophie's Sandwich Shop           None                NaN  US     NaN
# 2      Lovely Bridal Shop    Bridal Shop                NaN  US  Dallas
#
#          country  crossStreet  distance  \
# 0  United States  Worthington       275
# 1  United States          NaN       351
# 2  United States          NaN       521
#
#                                     formattedAddress  \
# 0  [2808 McKinney Ave (Worthington), Dallas, TX 7...
# 1                             [Texas, United States]
# 2                  [Dallas, TX 75204, United States]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 32.798288, 'lng':...  32.798288 -96.800445
# 1  [{'label': 'display', 'lat': 32.797851, 'lng':...  32.797851 -96.801450
# ...

# %%
dataframe_filtered.name
# Out:
# 0           Ann's Gift Shop
# 1    Sophie's Sandwich Shop
# 2        Lovely Bridal Shop
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Explore a Given Venue  (Restaurant)

# %%
search_query = 'MiddleEastern Restaurant'
radius = 500
print(search_query + ' .... OK!')


url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url


results = requests.get(url).json()
results


# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()


# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# MiddleEastern Restaurant .... OK!
#                             name          categories                 address  \
# 0               Tutto Restaurant                Food       2719 McKinney Ave
# 1         Bella Bar & Restaurant  Italian Restaurant  2626 Howell St Ste 100
# 2  City Council Restaurant & Bar                 Bar         2901 Thomas Ave
#
#    cc    city        country     crossStreet  distance  \
# 0  US  Dallas  United States             NaN       310
# 1  US  Dallas  United States             NaN       355
# 2  US  Dallas  United States  Thomas & Allen       506
#
#                                     formattedAddress  \
# 0  [2719 McKinney Ave, Dallas, TX 75204, United S...
# 1  [2626 Howell St Ste 100, Dallas, TX 75204, Uni...
# 2  [2901 Thomas Ave (Thomas & Allen), Dallas, TX ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 32.798202, 'lng':...  32.798202 -96.801309
# ...

# %%
dataframe_filtered.name
# Out:
# 0                 Tutto Restaurant
# 1           Bella Bar & Restaurant
# 2    City Council Restaurant & Bar
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Explore a Given Venue  (Medical Center)

# %%
search_query = 'Medical Center'
radius = 500
print(search_query + ' .... OK!')


url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url


results = requests.get(url).json()
results


# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()


# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# Medical Center .... OK!
#                                                  name  \
# 0                     Baylor Medical Center at Uptown
# 1                          Post Uptown Leasing Center
# 2                              Dallas Wellness Center
# 3                                 Eagle Postal Center
# 4                                       Uptown Center
# 5                              Biz Center/Club Monaco
# 6                                    Post Worthington
# 7                                Amlii Workout Center
# 8                      Texas Health Springwood Center
# 9                                      Leasing Center
# 10       Lemmon Avenue Plastic Surgery & Laser Center
# 11                     AmliQuadrangle Business Center
# 12              NutriMedical Wellness and Weight Loss
# 13                   Genesis Medical Consulting, Inc.
# 14                       Post Vineyard Fitness Center
# 15                               McKinney Uptown Pool
# ...

# %%
dataframe_filtered.name
# Out:
# 0                       Baylor Medical Center at Uptown
# 1                            Post Uptown Leasing Center
# 2                                Dallas Wellness Center
# 3                                   Eagle Postal Center
# 4                                         Uptown Center
# 5                                Biz Center/Club Monaco
# 6                                      Post Worthington
# 7                                  Amlii Workout Center
# 8                        Texas Health Springwood Center
# 9                                        Leasing Center
# 10         Lemmon Avenue Plastic Surgery & Laser Center
# 11                       AmliQuadrangle Business Center
# 12                NutriMedical Wellness and Weight Loss
# 13                     Genesis Medical Consulting, Inc.
# 14                         Post Vineyard Fitness Center
# 15                                 McKinney Uptown Pool
# 16                                  Post Fitness Center
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Explore a Given Venue  (School)

# %%
search_query = 'Public School'
radius = 500
print(search_query + ' .... OK!')


url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url


results = requests.get(url).json()
results


# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()


# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# Public School .... OK!
#                                name          categories  \
# 0                  The Public House                 Pub
# 1                  Publicis Hawkeye  Advertising Agency
# 2  The Reeds Public Relations Corp.              Office
#
#                  address  cc    city        country crossStreet  distance  \
# 0                    NaN  US  Dallas  United States         NaN       486
# 1  2828 Routh St Ste 300  US  Dallas  United States         NaN       450
# 2      3232 McKinney Ave  US  Dallas  United States    Hall St.       317
#
#                                     formattedAddress  \
# 0                        [Dallas, TX, United States]
# 1  [2828 Routh St Ste 300, Dallas, TX 75201, Unit...
# 2  [3232 McKinney Ave (Hall St.), Dallas, TX 7520...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 32.79767896426983...  32.797679 -96.803595
# ...

# %%
dataframe_filtered.name
# Out:
# 0                    The Public House
# 1                    Publicis Hawkeye
# 2    The Reeds Public Relations Corp.
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Explore a Given Venue  (Road)

# %%
search_query = 'HighWay'
radius = 500
print(search_query + ' .... OK!')


url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url


results = requests.get(url).json()
results


# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()


# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# HighWay .... OK!
#                    name categories                    address  cc    city  \
# 0            Katy Trail      Trail                 Katy Trail  US  Dallas
# 1  A Way Out Bail Bonds       None  3131 McKinney Ave Ste 600  US  Dallas
#
#          country                 crossStreet  distance  \
# 0  United States  bt Houston St & Airline Rd       383
# 1  United States                         NaN       224
#
#                                     formattedAddress  \
# 0  [Katy Trail (bt Houston St & Airline Rd), Dall...
# 1  [3131 McKinney Ave Ste 600, Dallas, TX 75204, ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 32.80392651681581...  32.803927 -96.801320
# 1  [{'label': 'display', 'lat': 32.8025315, 'lng'...  32.802532 -96.800898
#
#   postalCode state                        id
# 0      75204    TX  4bc23dfbabf49521923dc293
# 1      75204    TX  4f1d181e0cd67469c7c1f397

# %%
dataframe_filtered.name
# Out:
# 0              Katy Trail
# 1    A Way Out Bail Bonds
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests # library to handle requests

import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans


# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# WARNING conda.base.context:use_only_tar_bz2(632): Conda is constrained to only using the old .tar.bz2 file format because you have conda-build installed, and it is <3.18.3.  Update or remove conda-build to get smaller downloads and faster extractions.
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# WARNING conda.base.context:use_only_tar_bz2(632): Conda is constrained to only using the old .tar.bz2 file format because you have conda-build installed, and it is <3.18.3.  Update or remove conda-build to get smaller downloads and faster extractions.
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
Explore all the

# %%
address = 'Uptown, Dallas'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))




CLIENT_ID = 'IBMDHJ3EQQMYCEKTWBME1UADKR5CVT1DANIW4CZNXPCOIDY5' # your Foursquare ID
CLIENT_SECRET = 'VJVVBQN14QFTAR2DSG4JONF1ZPG2MCB3DOSKDC3RWJ14IYTG' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)






LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius



 # create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    location.latitude, 
    location.longitude, 
    radius, 
    LIMIT)
url # display URL




results = requests.get(url).json()
results



# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
    
    
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()



print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))



def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)



nearby_venues.head(20)
# Out:
# The geograpical coordinate of Toronto City are 32.8007124, -96.7998571.
# Your credentails:
# CLIENT_ID: IBMDHJ3EQQMYCEKTWBME1UADKR5CVT1DANIW4CZNXPCOIDY5
# CLIENT_SECRET:VJVVBQN14QFTAR2DSG4JONF1ZPG2MCB3DOSKDC3RWJ14IYTG
# 45 venues were returned by Foursquare.
#                            name           categories        lat        lng
# 0                     Starbucks          Coffee Shop  32.800318 -96.800940
# 1               iFratelli Pizza          Pizza Place  32.800599 -96.800962
# 2             San Martin Bakery               Bakery  32.802270 -96.800132
# 3             The Standard Pour         Cocktail Bar  32.799692 -96.800749
# 4         Blue Sushi Sake Grill  Japanese Restaurant  32.803211 -96.800005
# 5                   Salon Blanc   Salon / Barbershop  32.799324 -96.802282
# 6         Trophy Fitness Uptown                  Gym  32.799861 -96.801896
# 7                    Parliament         Cocktail Bar  32.797765 -96.798569
# ...

# %% [markdown]
# ### Result and conclusion

# %% [markdown]
# From we explore Uptown Dallas if palce has many attraction and close facilities
# to almost everything but we could not see and rate for the list of apartment.
# The good thing is the Katy Trail was close to all the apartments.
#
# Any was very good experiance of using Foursquare and learn how to find detial about the palce.
